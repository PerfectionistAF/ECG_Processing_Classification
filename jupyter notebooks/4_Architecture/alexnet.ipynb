# %%
#necessary libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2
import PIL.Image
import matplotlib 
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import shutil
import posixpath
import sys 
import glob
import wfdb
import pandas as pd
import math
from PIL import Image

# %%
#set CPU and GPU cores
tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 10})
# Out:
# device_count {
#   key: "GPU"
#   value: 1
# }
# device_count {
#   key: "CPU"
#   value: 10
# }

# %%
#run_opts = tf.RunOptions(report_tensor_allocations_upon_oom = True)

# %%
#(640, 480, 3)  ##original, too big tensors, use other sizes to decrease exhaustion of gpu 
#tf2 doesn't have runoptions, check above after trials
# 128,96,3  #(320, 240, 3)

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Bundle branch block'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Bundle branch block/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Bundle branch block/' + name)
# Out:
# 1164_multiple_ Bundle branch block.png
# 1165_multiple_ Bundle branch block.png
# 1166_multiple_ Bundle branch block.png
# 1182_multiple_ Bundle branch block.png
# 1183_multiple_ Bundle branch block.png
# 1184_multiple_ Bundle branch block.png
# 1284_multiple_ Bundle branch block.png
# 1285_multiple_ Bundle branch block.png
# 1286_multiple_ Bundle branch block.png
# 1296_multiple_ Bundle branch block.png
# 1297_multiple_ Bundle branch block.png
# 1298_multiple_ Bundle branch block.png
# 1299_multiple_ Bundle branch block.png
# 1300_multiple_ Bundle branch block.png
# 1301_multiple_ Bundle branch block.png
# 1302_multiple_ Bundle branch block.png
# 1303_multiple_ Bundle branch block.png
# 1304_multiple_ Bundle branch block.png
# 1305_multiple_ Bundle branch block.png
# 1306_multiple_ Bundle branch block.png
# 1307_multiple_ Bundle branch block.png
# 1311_multiple_ Bundle branch block.png
# 1312_multiple_ Bundle branch block.png
# 1313_multiple_ Bundle branch block.png
# ...

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Cardiomyopathy'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Cardiomyopathy/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Cardiomyopathy/' + name)
# Out:
# 1020_multiple_ Cardiomyopathy.png
# 1021_multiple_ Cardiomyopathy.png
# 1022_multiple_ Cardiomyopathy.png
# 1023_multiple_ Cardiomyopathy.png
# 1024_multiple_ Cardiomyopathy.png
# 1025_multiple_ Cardiomyopathy.png
# 1029_multiple_ Cardiomyopathy.png
# 1030_multiple_ Cardiomyopathy.png
# 1031_multiple_ Cardiomyopathy.png
# 1047_multiple_ Cardiomyopathy.png
# 1048_multiple_ Cardiomyopathy.png
# 1049_multiple_ Cardiomyopathy.png
# 1146_multiple_ Cardiomyopathy.png
# 1147_multiple_ Cardiomyopathy.png
# 1148_multiple_ Cardiomyopathy.png
# 1290_multiple_ Cardiomyopathy.png
# 1291_multiple_ Cardiomyopathy.png
# 1292_multiple_ Cardiomyopathy.png
# 1293_multiple_ Cardiomyopathy.png
# 1294_multiple_ Cardiomyopathy.png
# 1295_multiple_ Cardiomyopathy.png
# 1341_multiple_ Cardiomyopathy.png
# 1342_multiple_ Cardiomyopathy.png
# 1343_multiple_ Cardiomyopathy.png
# 1362_multiple_ Cardiomyopathy.png
# 1363_multiple_ Cardiomyopathy.png
# 1364_multiple_ Cardiomyopathy.png
# ...

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Dysrhythmia'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Dysrhythmia/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Dysrhythmia/' + name)
# Out:
# 1038_multiple_ Dysrhythmia.png
# 1039_multiple_ Dysrhythmia.png
# 1040_multiple_ Dysrhythmia.png
# 1077_multiple_ Dysrhythmia.png
# 1078_multiple_ Dysrhythmia.png
# 1079_multiple_ Dysrhythmia.png
# 1092_multiple_ Dysrhythmia.png
# 1093_multiple_ Dysrhythmia.png
# 1094_multiple_ Dysrhythmia.png
# 1098_multiple_ Dysrhythmia.png
# 1099_multiple_ Dysrhythmia.png
# 1100_multiple_ Dysrhythmia.png
# 1110_multiple_ Dysrhythmia.png
# 1111_multiple_ Dysrhythmia.png
# 1112_multiple_ Dysrhythmia.png
# 1149_multiple_ Dysrhythmia.png
# 1150_multiple_ Dysrhythmia.png
# 1151_multiple_ Dysrhythmia.png
# 1152_multiple_ Dysrhythmia.png
# 1153_multiple_ Dysrhythmia.png
# 1154_multiple_ Dysrhythmia.png
# 1188_multiple_ Dysrhythmia.png
# 1189_multiple_ Dysrhythmia.png
# 1190_multiple_ Dysrhythmia.png
# 1239_multiple_ Dysrhythmia.png
# 1240_multiple_ Dysrhythmia.png
# 1241_multiple_ Dysrhythmia.png
# 1350_multiple_ Dysrhythmia.png
# 1351_multiple_ Dysrhythmia.png
# 1352_multiple_ Dysrhythmia.png
# ...

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Healthy control'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Healthy control/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Healthy control/' + name)
# Out:
# 1005_multiple_ Healthy control.png
# 1006_multiple_ Healthy control.png
# 1007_multiple_ Healthy control.png
# 1008_multiple_ Healthy control.png
# 1009_multiple_ Healthy control.png
# 1010_multiple_ Healthy control.png
# 1035_multiple_ Healthy control.png
# 1036_multiple_ Healthy control.png
# 1037_multiple_ Healthy control.png
# 1089_multiple_ Healthy control.png
# 1090_multiple_ Healthy control.png
# 1091_multiple_ Healthy control.png
# 1104_multiple_ Healthy control.png
# 1105_multiple_ Healthy control.png
# 1106_multiple_ Healthy control.png
# 1107_multiple_ Healthy control.png
# 1108_multiple_ Healthy control.png
# 1109_multiple_ Healthy control.png
# 1137_multiple_ Healthy control.png
# 1138_multiple_ Healthy control.png
# 1139_multiple_ Healthy control.png
# 1140_multiple_ Healthy control.png
# 1141_multiple_ Healthy control.png
# 1142_multiple_ Healthy control.png
# 1143_multiple_ Healthy control.png
# 1144_multiple_ Healthy control.png
# 1145_multiple_ Healthy control.png
# ...

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 2)'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 2)/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 2)/' + name)
# Out:
# 984_multiple_ Heart failure (NYHA 2).png
# 985_multiple_ Heart failure (NYHA 2).png
# 986_multiple_ Heart failure (NYHA 2).png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 3)'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 3)/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 3)/' + name)
# Out:
# 996_multiple_ Heart failure (NYHA 3).png
# 997_multiple_ Heart failure (NYHA 3).png
# 998_multiple_ Heart failure (NYHA 3).png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 4)'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 4)/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Heart failure (NYHA 4)/' + name)
# Out:
# 1011_multiple_ Heart failure (NYHA 4).png
# 1012_multiple_ Heart failure (NYHA 4).png
# 1013_multiple_ Heart failure (NYHA 4).png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Hypertrophy'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Hypertrophy/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Hypertrophy/' + name)
# Out:
# 1119_multiple_ Hypertrophy.png
# 1120_multiple_ Hypertrophy.png
# 1121_multiple_ Hypertrophy.png
# 1326_multiple_ Hypertrophy.png
# 1327_multiple_ Hypertrophy.png
# 1328_multiple_ Hypertrophy.png
# 1332_multiple_ Hypertrophy.png
# 1333_multiple_ Hypertrophy.png
# 1334_multiple_ Hypertrophy.png
# 1344_multiple_ Hypertrophy.png
# 1345_multiple_ Hypertrophy.png
# 1346_multiple_ Hypertrophy.png
# 1359_multiple_ Hypertrophy.png
# 1360_multiple_ Hypertrophy.png
# 1361_multiple_ Hypertrophy.png
# 1380_multiple_ Hypertrophy.png
# 1381_multiple_ Hypertrophy.png
# 1382_multiple_ Hypertrophy.png
# 1476_multiple_ Hypertrophy.png
# 1477_multiple_ Hypertrophy.png
# 1478_multiple_ Hypertrophy.png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Myocardial Infarction'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Myocardial Infarction/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Myocardial Infarction/' + name)
# Out:
# 0_multiple_ Myocardial infarction.png
# 1002_multiple_ Myocardial infarction.png
# 1003_multiple_ Myocardial infarction.png
# 1004_multiple_ Myocardial infarction.png
# 100_multiple_ Myocardial infarction.png
# 101_multiple_ Myocardial infarction.png
# 1026_multiple_ Myocardial infarction.png
# 1027_multiple_ Myocardial infarction.png
# 1028_multiple_ Myocardial infarction.png
# 102_multiple_ Myocardial infarction.png
# 103_multiple_ Myocardial infarction.png
# 1041_multiple_ Myocardial infarction.png
# 1042_multiple_ Myocardial infarction.png
# 1043_multiple_ Myocardial infarction.png
# 104_multiple_ Myocardial infarction.png
# 1050_multiple_ Myocardial infarction.png
# 1051_multiple_ Myocardial infarction.png
# 1052_multiple_ Myocardial infarction.png
# 1053_multiple_ Myocardial infarction.png
# 1054_multiple_ Myocardial infarction.png
# 1055_multiple_ Myocardial infarction.png
# 1056_multiple_ Myocardial infarction.png
# 1057_multiple_ Myocardial infarction.png
# ...

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Myocarditis'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Myocarditis/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Myocarditis/' + name)
# Out:
# 1473_multiple_ Myocarditis.png
# 1474_multiple_ Myocarditis.png
# 1475_multiple_ Myocarditis.png
# 1539_multiple_ Myocarditis.png
# 1540_multiple_ Myocarditis.png
# 1541_multiple_ Myocarditis.png
# 1545_multiple_ Myocarditis.png
# 1546_multiple_ Myocarditis.png
# 1547_multiple_ Myocarditis.png
# 1548_multiple_ Myocarditis.png
# 1549_multiple_ Myocarditis.png
# 1550_multiple_ Myocarditis.png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Palpitation'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Palpitation/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Palpitation/' + name)
# Out:
# 1017_multiple_ Palpitation.png
# 1018_multiple_ Palpitation.png
# 1019_multiple_ Palpitation.png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Stable angina'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Stable angina/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Stable angina/' + name)
# Out:
# 1032_multiple_ Stable angina.png
# 1033_multiple_ Stable angina.png
# 1034_multiple_ Stable angina.png
# 1254_multiple_ Stable angina.png
# 1255_multiple_ Stable angina.png
# 1256_multiple_ Stable angina.png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Unqualified'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Unqualified/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Unqualified/' + name)
# Out:
# 1000_multiple_ Unqualified.png
# 1001_multiple_ Unqualified.png
# 1014_multiple_ Unqualified.png
# 1015_multiple_ Unqualified.png
# 1016_multiple_ Unqualified.png
# 1044_multiple_ Unqualified.png
# 1045_multiple_ Unqualified.png
# 1046_multiple_ Unqualified.png
# 1065_multiple_ Unqualified.png
# 1066_multiple_ Unqualified.png
# 1067_multiple_ Unqualified.png
# 1068_multiple_ Unqualified.png
# 1069_multiple_ Unqualified.png
# 1070_multiple_ Unqualified.png
# 1074_multiple_ Unqualified.png
# 1075_multiple_ Unqualified.png
# 1076_multiple_ Unqualified.png
# 1101_multiple_ Unqualified.png
# 1102_multiple_ Unqualified.png
# 1103_multiple_ Unqualified.png
# 1125_multiple_ Unqualified.png
# 1126_multiple_ Unqualified.png
# 1127_multiple_ Unqualified.png
# 1131_multiple_ Unqualified.png
# 1132_multiple_ Unqualified.png
# 1133_multiple_ Unqualified.png
# 1134_multiple_ Unqualified.png
# 1135_multiple_ Unqualified.png
# 1136_multiple_ Unqualified.png
# 1185_multiple_ Unqualified.png
# ...

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Unstable angina'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Unstable angina/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Unstable angina/' + name)
# Out:
# 1269_multiple_ Unstable angina.png
# 1270_multiple_ Unstable angina.png
# 1271_multiple_ Unstable angina.png

# %%
for image in os.listdir('./ptb_ecg_filtered/train_multi/Valvular heart disease'):
    print(image)
    name = os.path.basename(image)
    image = Image.open('./ptb_ecg_filtered/train_multi/Valvular heart disease/' + image)
    resized_image = image.resize((320, 240))
    # Save the resized image
    resized_image.save('./ptb_ecg_filtered/train_multi/Valvular heart disease/' + name)
# Out:
# 1242_multiple_ Valvular heart disease.png
# 1243_multiple_ Valvular heart disease.png
# 1244_multiple_ Valvular heart disease.png
# 1371_multiple_ Valvular heart disease.png
# 1372_multiple_ Valvular heart disease.png
# 1373_multiple_ Valvular heart disease.png
# 954_multiple_ Valvular heart disease.png
# 955_multiple_ Valvular heart disease.png
# 956_multiple_ Valvular heart disease.png
# 957_multiple_ Valvular heart disease.png
# 958_multiple_ Valvular heart disease.png
# 959_multiple_ Valvular heart disease.png
# 966_multiple_ Valvular heart disease.png
# 967_multiple_ Valvular heart disease.png
# 968_multiple_ Valvular heart disease.png
# 981_multiple_ Valvular heart disease.png
# 982_multiple_ Valvular heart disease.png
# 983_multiple_ Valvular heart disease.png

# %%
input_shape = (320, 240, 3)#(int(input_shape[0] * 2), int(input_shape[1] * 2), 3)
print(input_shape)
# Out:
# (320, 240, 3)

# %%
# Define the CNN model
model = keras.Sequential([
    layers.Conv2D(96, kernel_size=(11,11), strides= 4,
                        padding= 'valid', activation= 'relu',
                        input_shape= input_shape,
                        kernel_initializer= 'he_normal'),
    layers.MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None),
    layers.Conv2D(256, kernel_size=(5,5), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'),
    layers.MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None),
    layers.Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'),
    layers.Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'),
    layers.Conv2D(256, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'),
    layers.MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None),
    layers.Flatten(),
    layers.Dense(4096, activation= 'relu'),
    layers.Dense(4096, activation= 'relu'),
    layers.Dense(1000, activation= 'relu'),
    layers.Dense(15, activation='softmax')  # 15 output classes for Sparse and Categorical
    #layers.Dense(15, activation='sigmoid')  # 15 output classes for Binary
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              #loss=tf.keras.losses.CategoricalCrossentropy(),
              #loss=tf.keras.losses.BinaryCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Load and preprocess the dataset
# Assuming you have a folder containing images for each class,
# where each class is stored in a separate subfolder.
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    './ptb_ecg_filtered/train_multi',
    #'/path/to/train_dataset',E:\Jupyter\A_DNN\ptb_ecg_filtered\train
    image_size=(320, 240),
    batch_size=32
    #validation_split=0.2,
    #subset='training',
    #seed=123  ##no weights initialized here by deafult so not used
)
# Out:
# Found 1647 files belonging to 15 classes.

# %%
###TEST ONLY TRAINING ACCURACIES
'''validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    './ptb_ecg_filtered/train',
    image_size=(320, 240),
    batch_size=32,
    #validation_split=0.2,
    #subset='validation',
    #seed=123
)'''
# Out:
# Found 101 files belonging to 15 classes.
# Using 20 files for validation.

# %%
# Train the model
model.fit(
    train_dataset,
    #validation_data=validation_dataset,
    epochs=5
)
# Out:
# Epoch 1/10
# 52/52 [==============================] - 349s 6s/step - loss: 966.8329 - accuracy: 0.4366
# Epoch 2/10
# 52/52 [==============================] - 259s 5s/step - loss: 1.2680 - accuracy: 0.6703
# Epoch 3/10
# 52/52 [==============================] - 258s 5s/step - loss: 1.2490 - accuracy: 0.6703
# Epoch 4/10
# 52/52 [==============================] - 331s 6s/step - loss: 1.2344 - accuracy: 0.6703
# Epoch 5/10
# 52/52 [==============================] - 410s 8s/step - loss: 1.2095 - accuracy: 0.6673
# Epoch 6/10
# 14/52 [=======>......................] - ETA: 4:42 - loss: 1.2495 - accuracy: 0.6562
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Train the model
# ----> 2 model.fit(
#       3     train_dataset,
#       4     #validation_data=validation_dataset,
#       5     epochs=10
#       6 )
#
# ...

# %%
model.save('./models/alexnet_multiple_channel_model.keras')

# %% [markdown]
# ### TESTING

# %% [raw]
# model = keras.models.load_model('/path/to/trained_model.h5')
#
# # Load and preprocess the test dataset
# test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
#     '/path/to/test_dataset',
#     image_size=(64, 64),
#     batch_size=32,
#     seed=123
# )
#
# # Obtain the predicted classes for the test images
# predictions = model.predict(test_dataset)
# predicted_classes = tf.argmax(predictions, axis=1)
#
# # Get the class labels
# class_labels = test_dataset.class_names
#
# # Print the predicted classes for each image
# for image, predicted_class in zip(test_dataset, predicted_classes):
#     print(f"Predicted class: {class_labels[predicted_class]}")
